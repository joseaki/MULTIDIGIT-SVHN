# %%
from dataset import svhn_dataset, toPIL
import matplotlib.pyplot as plt
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from train import train_model
import model
import numpy as np

# %% [markdown]
# # Load dataset

# %%
test_dataset = svhn_dataset("./data/SVHN/test",
                            transform=transforms.Compose(
                                [transforms.ToTensor(), 
                                 transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                 ])
                            )

train_dataset = svhn_dataset("./data/SVHN/train",
                             transform=transforms.Compose(
                                 [toPIL(),
                                  transforms.RandomChoice(
                                      [transforms.ColorJitter(brightness=[0.5,0.8],
                                                              contrast=[0.4,0.5],
                                                              saturation=[0,1]),
                                       transforms.RandomRotation(degrees=30)]),
                                  transforms.ColorJitter(hue=[-0.5,0.5]),
                                  transforms.ToTensor(),
                                  transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                  ])
                             )

extra_dataset = svhn_dataset("./data/SVHN/extra",
                             transform=transforms.Compose(
                                 [transforms.ToTensor(),
                                  transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                  ])
                             )
# Out:
# loading data from ./data/SVHN/test
# loading data from ./data/SVHN/train
# loading data from ./data/SVHN/extra

# %%
train_loader = DataLoader(train_dataset, batch_size = 256, num_workers = 0, shuffle = True, drop_last = True)
validation_loader = DataLoader(test_dataset, batch_size = 256, num_workers = 0, shuffle = True, drop_last = True)
test_loader = DataLoader(extra_dataset, batch_size = 128, num_workers = 0, shuffle = True, drop_last = True)

# %%
print("training set has {} batches ".format(len(train_loader)))
print("validation set has {} batches ".format(len(validation_loader)))
print("test set has {} batches ".format(len(test_loader)))
# Out:
# training set has 130 batches
# validation set has 51 batches
# test set has 1580 batches

# %% [markdown]
# ## Plot a random image

# %%
rnd = random.randint(0,10000)
image = train_dataset[rnd]["image"]
plt.figure()
plt.imshow(image.permute(1,2,0)[:,:,0])

# %% [markdown]
# # Train the model

# %%
# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

scratch_model = model.vgg11_bn()

# Print the model we just instantiated
# print(scratch_model)

#params_to_update = scratch_model.parameters()
#print("Params to learn:")

#for name,param in scratch_model.named_parameters():
#    if param.requires_grad == True:
#        print("\t",name)

dataloaders_dict = {"train":train_loader,"val":validation_loader}
scratch_model = scratch_model.to(device)
scratch_optimizer = optim.Adam(scratch_model.parameters(), lr=0.0001)
scratch_criterion = nn.CrossEntropyLoss()
best_model, scratch_hist = train_model(scratch_model, dataloaders_dict, scratch_criterion, scratch_optimizer, device, num_epochs=150)
# Out:
# Epoch 0/149
# ----------
# train Loss: 1.1805 Acc: 0.5890
# Predicciones tensor([10, 10, 10,  3,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  0], device='cuda:0')
# val Loss: 0.9882 Acc: 0.6409
#
# Epoch 1/149
# ----------
# train Loss: 1.0208 Acc: 0.6410
# Predicciones tensor([10, 10, 10,  2,  1], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  0], device='cuda:0')
# val Loss: 0.7983 Acc: 0.7276
#
# Epoch 2/149
# ----------
# train Loss: 0.7664 Acc: 0.7346
# Predicciones tensor([10, 10,  1,  2,  0], device='cuda:0')
# Real ....... tensor([10, 10,  1,  3,  7], device='cuda:0')
# val Loss: 0.4848 Acc: 0.8360
#
# Epoch 3/149
# ----------
# train Loss: 0.5466 Acc: 0.8136
# Predicciones tensor([10, 10, 10, 10,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  2], device='cuda:0')
# val Loss: 0.3609 Acc: 0.8839
#
# Epoch 4/149
# ----------
# train Loss: 0.4185 Acc: 0.8599
# Predicciones tensor([10, 10, 10,  5,  8], device='cuda:0')
# Real ....... tensor([10, 10, 10,  5,  8], device='cuda:0')
# val Loss: 0.2922 Acc: 0.9066
#
# Epoch 5/149
# ----------
# train Loss: 0.3431 Acc: 0.8860
# Predicciones tensor([10, 10, 10, 10,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  7], device='cuda:0')
# val Loss: 0.2419 Acc: 0.9238
#
# Epoch 6/149
# ----------
# train Loss: 0.2967 Acc: 0.9010
# Predicciones tensor([10, 10, 10,  5,  1], device='cuda:0')
# Real ....... tensor([10, 10, 10,  5,  1], device='cuda:0')
# val Loss: 0.2524 Acc: 0.9230
#
# Epoch 7/149
# ----------
# train Loss: 0.2628 Acc: 0.9121
# Predicciones tensor([10, 10, 10,  2,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  3], device='cuda:0')
# val Loss: 0.2046 Acc: 0.9379
#
# Epoch 8/149
# ----------
# train Loss: 0.2344 Acc: 0.9214
# Predicciones tensor([10, 10, 10,  2,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  2], device='cuda:0')
# val Loss: 0.1982 Acc: 0.9404
#
# Epoch 9/149
# ----------
# train Loss: 0.2100 Acc: 0.9287
# Predicciones tensor([10, 10, 10, 10,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  7], device='cuda:0')
# val Loss: 0.2036 Acc: 0.9389
#
# Epoch 10/149
# ----------
# train Loss: 0.1945 Acc: 0.9342
# Predicciones tensor([10, 10,  1,  0,  1], device='cuda:0')
# Real ....... tensor([10, 10,  1,  0,  1], device='cuda:0')
# val Loss: 0.1937 Acc: 0.9423
#
# Epoch 11/149
# ----------
# train Loss: 0.1764 Acc: 0.9408
# Predicciones tensor([10, 10, 10,  4,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  5], device='cuda:0')
# val Loss: 0.2038 Acc: 0.9419
#
# Epoch 12/149
# ----------
# train Loss: 0.1625 Acc: 0.9445
# Predicciones tensor([10, 10,  1,  1,  9], device='cuda:0')
# Real ....... tensor([10, 10,  1,  1,  9], device='cuda:0')
# val Loss: 0.1915 Acc: 0.9445
#
# Epoch 13/149
# ----------
# train Loss: 0.1503 Acc: 0.9483
# Predicciones tensor([10, 10, 10,  1,  6], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  6], device='cuda:0')
# val Loss: 0.1782 Acc: 0.9497
#
# Epoch 14/149
# ----------
# train Loss: 0.1381 Acc: 0.9519
# Predicciones tensor([10, 10, 10,  9,  1], device='cuda:0')
# Real ....... tensor([10, 10, 10,  9,  1], device='cuda:0')
# val Loss: 0.1874 Acc: 0.9481
#
# Epoch 15/149
# ----------
# train Loss: 0.1291 Acc: 0.9548
# Predicciones tensor([10, 10,  2,  5,  7], device='cuda:0')
# Real ....... tensor([10, 10,  2,  6,  7], device='cuda:0')
# val Loss: 0.1702 Acc: 0.9529
#
# Epoch 16/149
# ----------
# train Loss: 0.1179 Acc: 0.9590
# Predicciones tensor([10, 10, 10,  4,  3], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  8], device='cuda:0')
# val Loss: 0.1713 Acc: 0.9534
#
# Epoch 17/149
# ----------
# train Loss: 0.1120 Acc: 0.9604
# Predicciones tensor([10, 10, 10,  4,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  5], device='cuda:0')
# val Loss: 0.1818 Acc: 0.9500
#
# Epoch 18/149
# ----------
# train Loss: 0.1019 Acc: 0.9637
# Predicciones tensor([10, 10, 10,  2,  3], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  3], device='cuda:0')
# val Loss: 0.1828 Acc: 0.9538
#
# Epoch 19/149
# ----------
# train Loss: 0.0973 Acc: 0.9649
# Predicciones tensor([10, 10,  4,  4,  3], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  3], device='cuda:0')
# val Loss: 0.1858 Acc: 0.9531
#
# Epoch 20/149
# ----------
# train Loss: 0.0929 Acc: 0.9666
# Predicciones tensor([10, 10,  2,  4,  1], device='cuda:0')
# Real ....... tensor([10, 10,  2,  4,  1], device='cuda:0')
# val Loss: 0.1881 Acc: 0.9503
#
# Epoch 21/149
# ----------
# train Loss: 0.0876 Acc: 0.9687
# Predicciones tensor([10, 10, 10,  1,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  9], device='cuda:0')
# val Loss: 0.1891 Acc: 0.9523
#
# Epoch 22/149
# ----------
# train Loss: 0.0826 Acc: 0.9700
# Predicciones tensor([10, 10, 10,  6,  0], device='cuda:0')
# Real ....... tensor([10, 10, 10,  6,  0], device='cuda:0')
# val Loss: 0.1880 Acc: 0.9536
#
# Epoch 23/149
# ----------
# train Loss: 0.0775 Acc: 0.9713
# Predicciones tensor([10, 10, 10,  5,  1], device='cuda:0')
# Real ....... tensor([10, 10, 10,  5,  1], device='cuda:0')
# val Loss: 0.1853 Acc: 0.9549
#
# Epoch 24/149
# ----------
# train Loss: 0.0749 Acc: 0.9724
# Predicciones tensor([10, 10, 10, 10,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  2], device='cuda:0')
# val Loss: 0.2017 Acc: 0.9527
#
# Epoch 25/149
# ----------
# train Loss: 0.0697 Acc: 0.9737
# Predicciones tensor([10, 10, 10,  6,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  9], device='cuda:0')
# val Loss: 0.1798 Acc: 0.9562
#
# Epoch 26/149
# ----------
# train Loss: 0.0644 Acc: 0.9754
# Predicciones tensor([10, 10, 10,  1,  6], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  5], device='cuda:0')
# val Loss: 0.1967 Acc: 0.9544
#
# Epoch 27/149
# ----------
# train Loss: 0.0616 Acc: 0.9764
# Predicciones tensor([10, 10, 10,  2,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  7], device='cuda:0')
# val Loss: 0.2055 Acc: 0.9521
#
# Epoch 28/149
# ----------
# train Loss: 0.0581 Acc: 0.9775
# Predicciones tensor([10, 10, 10, 10,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  9], device='cuda:0')
# val Loss: 0.1871 Acc: 0.9588
#
# Epoch 29/149
# ----------
# train Loss: 0.0583 Acc: 0.9777
# Predicciones tensor([10, 10,  3,  4,  5], device='cuda:0')
# Real ....... tensor([10, 10,  3,  4,  5], device='cuda:0')
# val Loss: 0.2134 Acc: 0.9502
#
# Epoch 30/149
# ----------
# train Loss: 0.0545 Acc: 0.9784
# Predicciones tensor([10, 10,  1,  3,  2], device='cuda:0')
# Real ....... tensor([10, 10,  1,  3,  2], device='cuda:0')
# val Loss: 0.2219 Acc: 0.9518
#
# Epoch 31/149
# ----------
# train Loss: 0.0513 Acc: 0.9795
# Predicciones tensor([10, 10, 10,  2,  0], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  0], device='cuda:0')
# val Loss: 0.2120 Acc: 0.9559
#
# Epoch 32/149
# ----------
# train Loss: 0.0513 Acc: 0.9798
# Predicciones tensor([10, 10, 10,  4,  0], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  0], device='cuda:0')
# val Loss: 0.2041 Acc: 0.9561
#
# Epoch 33/149
# ----------
# train Loss: 0.0485 Acc: 0.9806
# Predicciones tensor([10, 10,  1,  7,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  7,  6], device='cuda:0')
# val Loss: 0.2330 Acc: 0.9512
#
# Epoch 34/149
# ----------
# train Loss: 0.0475 Acc: 0.9809
# Predicciones tensor([10, 10, 10,  1,  0], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  0], device='cuda:0')
# val Loss: 0.2298 Acc: 0.9500
#
# Epoch 35/149
# ----------
# train Loss: 0.0437 Acc: 0.9823
# Predicciones tensor([10, 10, 10,  1,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  5], device='cuda:0')
# val Loss: 0.2125 Acc: 0.9574
#
# Epoch 36/149
# ----------
# train Loss: 0.0442 Acc: 0.9818
# Predicciones tensor([10, 10, 10, 10,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  2], device='cuda:0')
# val Loss: 0.2171 Acc: 0.9561
#
# Epoch 37/149
# ----------
# train Loss: 0.0427 Acc: 0.9825
# Predicciones tensor([10, 10, 10,  4,  1], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  1], device='cuda:0')
# val Loss: 0.2093 Acc: 0.9565
#
# Epoch 38/149
# ----------
# train Loss: 0.0405 Acc: 0.9832
# Predicciones tensor([10, 10, 10,  7,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10,  7,  2], device='cuda:0')
# val Loss: 0.2043 Acc: 0.9582
#
# Epoch 39/149
# ----------
# train Loss: 0.0384 Acc: 0.9842
# Predicciones tensor([10, 10, 10,  2,  8], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  6], device='cuda:0')
# val Loss: 0.2293 Acc: 0.9560
#
# Epoch 40/149
# ----------
# train Loss: 0.0356 Acc: 0.9843
# Predicciones tensor([10, 10,  6,  2,  6], device='cuda:0')
# Real ....... tensor([10, 10,  6,  2,  6], device='cuda:0')
# val Loss: 0.2004 Acc: 0.9598
#
# Epoch 41/149
# ----------
# train Loss: 0.0366 Acc: 0.9844
# Predicciones tensor([10, 10, 10,  2,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  5], device='cuda:0')
# val Loss: 0.2037 Acc: 0.9588
#
# Epoch 42/149
# ----------
# train Loss: 0.0358 Acc: 0.9846
# Predicciones tensor([10, 10,  1,  3,  1], device='cuda:0')
# Real ....... tensor([10, 10,  1,  3,  1], device='cuda:0')
# val Loss: 0.2166 Acc: 0.9569
#
# Epoch 43/149
# ----------
# train Loss: 0.0352 Acc: 0.9848
# Predicciones tensor([10, 10, 10, 10,  6], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  6], device='cuda:0')
# val Loss: 0.2429 Acc: 0.9532
#
# Epoch 44/149
# ----------
# train Loss: 0.0346 Acc: 0.9852
# Predicciones tensor([10, 10, 10,  7,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10,  7,  2], device='cuda:0')
# val Loss: 0.2104 Acc: 0.9581
#
# Epoch 45/149
# ----------
# train Loss: 0.0339 Acc: 0.9852
# Predicciones tensor([10, 10,  1,  1,  1], device='cuda:0')
# Real ....... tensor([10, 10,  1,  1,  1], device='cuda:0')
# val Loss: 0.2208 Acc: 0.9552
#
# Epoch 46/149
# ----------
# train Loss: 0.0316 Acc: 0.9859
# Predicciones tensor([10, 10, 10,  6,  3], device='cuda:0')
# Real ....... tensor([10, 10, 10,  6,  3], device='cuda:0')
# val Loss: 0.2381 Acc: 0.9585
#
# Epoch 47/149
# ----------
# train Loss: 0.0321 Acc: 0.9857
# Predicciones tensor([10, 10, 10,  1,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  5], device='cuda:0')
# val Loss: 0.2327 Acc: 0.9555
#
# Epoch 48/149
# ----------
# train Loss: 0.0303 Acc: 0.9862
# Predicciones tensor([10, 10, 10,  5,  1], device='cuda:0')
# Real ....... tensor([10, 10, 10,  5,  1], device='cuda:0')
# val Loss: 0.2394 Acc: 0.9569
#
# Epoch 49/149
# ----------
# train Loss: 0.0296 Acc: 0.9866
# Predicciones tensor([10, 10, 10,  2,  4], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  4], device='cuda:0')
# val Loss: 0.2188 Acc: 0.9584
#
# Epoch 50/149
# ----------
# train Loss: 0.0299 Acc: 0.9863
# Predicciones tensor([10, 10, 10,  4,  0], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  0], device='cuda:0')
# val Loss: 0.2700 Acc: 0.9513
#
# Epoch 51/149
# ----------
# train Loss: 0.0285 Acc: 0.9869
# Predicciones tensor([10, 10, 10,  2,  3], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  3], device='cuda:0')
# val Loss: 0.2224 Acc: 0.9578
#
# Epoch 52/149
# ----------
# train Loss: 0.0275 Acc: 0.9873
# Predicciones tensor([10, 10, 10,  3,  4], device='cuda:0')
# Real ....... tensor([10, 10, 10,  3,  4], device='cuda:0')
# val Loss: 0.2337 Acc: 0.9594
#
# Epoch 53/149
# ----------
# train Loss: 0.0270 Acc: 0.9874
# Predicciones tensor([10, 10, 10,  3,  3], device='cuda:0')
# Real ....... tensor([10, 10, 10,  3,  3], device='cuda:0')
# val Loss: 0.2423 Acc: 0.9566
#
# Epoch 54/149
# ----------
# train Loss: 0.0285 Acc: 0.9868
# Predicciones tensor([10, 10, 10,  6,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  6,  5], device='cuda:0')
# val Loss: 0.2337 Acc: 0.9574
#
# Epoch 55/149
# ----------
# train Loss: 0.0247 Acc: 0.9881
# Predicciones tensor([10, 10, 10,  9,  0], device='cuda:0')
# Real ....... tensor([10, 10, 10,  9,  0], device='cuda:0')
# val Loss: 0.2528 Acc: 0.9566
#
# Epoch 56/149
# ----------
# train Loss: 0.0251 Acc: 0.9881
# Predicciones tensor([10, 10, 10,  1,  1], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  1], device='cuda:0')
# val Loss: 0.2505 Acc: 0.9555
#
# Epoch 57/149
# ----------
# train Loss: 0.0246 Acc: 0.9882
# Predicciones tensor([10, 10, 10,  9,  8], device='cuda:0')
# Real ....... tensor([10, 10, 10,  9,  8], device='cuda:0')
# val Loss: 0.2306 Acc: 0.9586
#
# Epoch 58/149
# ----------
# train Loss: 0.0247 Acc: 0.9881
# Predicciones tensor([10, 10, 10,  3,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  3,  5], device='cuda:0')
# val Loss: 0.2367 Acc: 0.9571
#
# Epoch 59/149
# ----------
# train Loss: 0.0267 Acc: 0.9873
# Predicciones tensor([10, 10,  4,  2,  5], device='cuda:0')
# Real ....... tensor([10, 10,  4,  2,  5], device='cuda:0')
# val Loss: 0.2677 Acc: 0.9548
#
# Epoch 60/149
# ----------
# train Loss: 0.0229 Acc: 0.9890
# Predicciones tensor([10, 10, 10,  2,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  7], device='cuda:0')
# val Loss: 0.2260 Acc: 0.9600
#
# Epoch 61/149
# ----------
# train Loss: 0.0224 Acc: 0.9890
# Predicciones tensor([10, 10,  1,  1,  0], device='cuda:0')
# Real ....... tensor([10, 10,  1,  1,  0], device='cuda:0')
# val Loss: 0.2187 Acc: 0.9605
#
# Epoch 62/149
# ----------
# train Loss: 0.0230 Acc: 0.9890
# Predicciones tensor([10, 10, 10,  1,  0], device='cuda:0')
# Real ....... tensor([10, 10, 10,  3,  0], device='cuda:0')
# val Loss: 0.2514 Acc: 0.9557
#
# Epoch 63/149
# ----------
# train Loss: 0.0217 Acc: 0.9894
# Predicciones tensor([10, 10, 10,  6,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10,  6,  2], device='cuda:0')
# val Loss: 0.2460 Acc: 0.9590
#
# Epoch 64/149
# ----------
# train Loss: 0.0225 Acc: 0.9890
# Predicciones tensor([10, 10, 10, 10,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  9], device='cuda:0')
# val Loss: 0.2266 Acc: 0.9599
#
# Epoch 65/149
# ----------
# train Loss: 0.0220 Acc: 0.9892
# Predicciones tensor([10,  4,  0,  5,  7], device='cuda:0')
# Real ....... tensor([10,  1,  0,  5,  7], device='cuda:0')
# val Loss: 0.2307 Acc: 0.9596
#
# Epoch 66/149
# ----------
# train Loss: 0.0213 Acc: 0.9895
# Predicciones tensor([10, 10, 10,  5,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10,  5,  9], device='cuda:0')
# val Loss: 0.2620 Acc: 0.9563
#
# Epoch 67/149
# ----------
# train Loss: 0.0208 Acc: 0.9896
# Predicciones tensor([10, 10, 10,  6,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10,  6,  3], device='cuda:0')
# val Loss: 0.2559 Acc: 0.9582
#
# Epoch 68/149
# ----------
# train Loss: 0.0206 Acc: 0.9897
# Predicciones tensor([10, 10, 10, 10,  6], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  6], device='cuda:0')
# val Loss: 0.2354 Acc: 0.9607
#
# Epoch 69/149
# ----------
# train Loss: 0.0196 Acc: 0.9899
# Predicciones tensor([10, 10, 10, 10,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  2], device='cuda:0')
# val Loss: 0.2582 Acc: 0.9579
#
# Epoch 70/149
# ----------
# train Loss: 0.0196 Acc: 0.9899
# Predicciones tensor([10, 10, 10,  1,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  7], device='cuda:0')
# val Loss: 0.2367 Acc: 0.9596
#
# Epoch 71/149
# ----------
# train Loss: 0.0204 Acc: 0.9899
# Predicciones tensor([10, 10, 10,  4,  8], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  8], device='cuda:0')
# val Loss: 0.2498 Acc: 0.9598
#
# Epoch 72/149
# ----------
# train Loss: 0.0189 Acc: 0.9898
# Predicciones tensor([10, 10, 10,  4,  3], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  3], device='cuda:0')
# val Loss: 0.2541 Acc: 0.9581
#
# Epoch 73/149
# ----------
# train Loss: 0.0183 Acc: 0.9903
# Predicciones tensor([10, 10,  1,  1,  3], device='cuda:0')
# Real ....... tensor([10, 10,  1,  1,  3], device='cuda:0')
# val Loss: 0.2477 Acc: 0.9591
#
# Epoch 74/149
# ----------
# train Loss: 0.0178 Acc: 0.9904
# Predicciones tensor([10, 10, 10,  3,  4], device='cuda:0')
# Real ....... tensor([10, 10, 10,  3,  0], device='cuda:0')
# val Loss: 0.2365 Acc: 0.9617
#
# Epoch 75/149
# ----------
# train Loss: 0.0174 Acc: 0.9906
# Predicciones tensor([10, 10, 10, 10,  6], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  6], device='cuda:0')
# val Loss: 0.2749 Acc: 0.9575
#
# Epoch 76/149
# ----------
# train Loss: 0.0191 Acc: 0.9901
# Predicciones tensor([10, 10, 10, 10,  3], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  3], device='cuda:0')
# val Loss: 0.2837 Acc: 0.9544
#
# Epoch 77/149
# ----------
# train Loss: 0.0192 Acc: 0.9902
# Predicciones tensor([10, 10, 10,  5,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10,  5,  9], device='cuda:0')
# val Loss: 0.2660 Acc: 0.9576
#
# Epoch 78/149
# ----------
# train Loss: 0.0193 Acc: 0.9900
# Predicciones tensor([10, 10, 10,  1,  4], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  4], device='cuda:0')
# val Loss: 0.2536 Acc: 0.9595
#
# Epoch 79/149
# ----------
# train Loss: 0.0184 Acc: 0.9902
# Predicciones tensor([10, 10, 10,  1,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  5], device='cuda:0')
# val Loss: 0.2474 Acc: 0.9594
#
# Epoch 80/149
# ----------
# train Loss: 0.0161 Acc: 0.9912
# Predicciones tensor([10, 10, 10,  2,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  5], device='cuda:0')
# val Loss: 0.2551 Acc: 0.9610
#
# Epoch 81/149
# ----------
# train Loss: 0.0180 Acc: 0.9906
# Predicciones tensor([10, 10, 10,  4,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  2], device='cuda:0')
# val Loss: 0.2576 Acc: 0.9600
#
# Epoch 82/149
# ----------
# train Loss: 0.0173 Acc: 0.9910
# Predicciones tensor([10, 10, 10,  1,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  5], device='cuda:0')
# val Loss: 0.2474 Acc: 0.9603
#
# Epoch 83/149
# ----------
# train Loss: 0.0159 Acc: 0.9913
# Predicciones tensor([10, 10,  1,  4,  3], device='cuda:0')
# Real ....... tensor([10, 10,  1,  4,  3], device='cuda:0')
# val Loss: 0.2544 Acc: 0.9594
#
# Epoch 84/149
# ----------
# train Loss: 0.0152 Acc: 0.9914
# Predicciones tensor([10, 10,  1,  5,  0], device='cuda:0')
# Real ....... tensor([10, 10,  1,  5,  0], device='cuda:0')
# val Loss: 0.2513 Acc: 0.9608
#
# Epoch 85/149
# ----------
# train Loss: 0.0166 Acc: 0.9909
# Predicciones tensor([10, 10, 10,  3,  3], device='cuda:0')
# Real ....... tensor([10, 10, 10,  3,  3], device='cuda:0')
# val Loss: 0.2798 Acc: 0.9584
#
# Epoch 86/149
# ----------
# train Loss: 0.0169 Acc: 0.9909
# Predicciones tensor([10, 10,  1,  7,  4], device='cuda:0')
# Real ....... tensor([10, 10,  1,  7,  4], device='cuda:0')
# val Loss: 0.2895 Acc: 0.9556
#
# Epoch 87/149
# ----------
# train Loss: 0.0160 Acc: 0.9911
# Predicciones tensor([10, 10, 10,  2,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  9], device='cuda:0')
# val Loss: 0.2520 Acc: 0.9615
#
# Epoch 88/149
# ----------
# train Loss: 0.0146 Acc: 0.9916
# Predicciones tensor([10, 10,  1,  2,  7], device='cuda:0')
# Real ....... tensor([10, 10,  1,  2,  7], device='cuda:0')
# val Loss: 0.2755 Acc: 0.9594
#
# Epoch 89/149
# ----------
# train Loss: 0.0164 Acc: 0.9910
# Predicciones tensor([10, 10,  6,  4,  2], device='cuda:0')
# Real ....... tensor([10, 10,  3,  4,  2], device='cuda:0')
# val Loss: 0.2485 Acc: 0.9605
#
# Epoch 90/149
# ----------
# train Loss: 0.0154 Acc: 0.9915
# Predicciones tensor([10, 10, 10,  4,  3], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  3], device='cuda:0')
# val Loss: 0.2685 Acc: 0.9587
#
# Epoch 91/149
# ----------
# train Loss: 0.0143 Acc: 0.9916
# Predicciones tensor([10, 10,  2,  2,  2], device='cuda:0')
# Real ....... tensor([10, 10,  2,  2,  2], device='cuda:0')
# val Loss: 0.2695 Acc: 0.9578
#
# Epoch 92/149
# ----------
# train Loss: 0.0145 Acc: 0.9916
# Predicciones tensor([10, 10, 10, 10,  8], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  8], device='cuda:0')
# val Loss: 0.2562 Acc: 0.9598
#
# Epoch 93/149
# ----------
# train Loss: 0.0140 Acc: 0.9918
# Predicciones tensor([10, 10, 10,  1,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  9], device='cuda:0')
# val Loss: 0.2944 Acc: 0.9569
#
# Epoch 94/149
# ----------
# train Loss: 0.0156 Acc: 0.9913
# Predicciones tensor([10, 10, 10,  2,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  5], device='cuda:0')
# val Loss: 0.2630 Acc: 0.9598
#
# Epoch 95/149
# ----------
# train Loss: 0.0130 Acc: 0.9922
# Predicciones tensor([10, 10, 10, 10,  8], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  3], device='cuda:0')
# val Loss: 0.2838 Acc: 0.9580
#
# Epoch 96/149
# ----------
# train Loss: 0.0158 Acc: 0.9913
# Predicciones tensor([10, 10,  1,  5,  5], device='cuda:0')
# Real ....... tensor([10, 10,  1,  5,  3], device='cuda:0')
# val Loss: 0.2546 Acc: 0.9601
#
# Epoch 97/149
# ----------
# train Loss: 0.0148 Acc: 0.9914
# Predicciones tensor([10, 10, 10,  4,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  7], device='cuda:0')
# val Loss: 0.2634 Acc: 0.9580
#
# Epoch 98/149
# ----------
# train Loss: 0.0124 Acc: 0.9923
# Predicciones tensor([10, 10, 10,  2,  3], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  3], device='cuda:0')
# val Loss: 0.2747 Acc: 0.9599
#
# Epoch 99/149
# ----------
# train Loss: 0.0119 Acc: 0.9923
# Predicciones tensor([10, 10, 10, 10,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  5], device='cuda:0')
# val Loss: 0.2867 Acc: 0.9576
#
# Epoch 100/149
# ----------
# train Loss: 0.0156 Acc: 0.9913
# Predicciones tensor([10, 10, 10,  1,  4], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  4], device='cuda:0')
# val Loss: 0.2871 Acc: 0.9587
#
# Epoch 101/149
# ----------
# train Loss: 0.0147 Acc: 0.9915
# Predicciones tensor([10, 10,  2,  7,  2], device='cuda:0')
# Real ....... tensor([10, 10,  2,  7,  2], device='cuda:0')
# val Loss: 0.2567 Acc: 0.9615
#
# Epoch 102/149
# ----------
# train Loss: 0.0130 Acc: 0.9922
# Predicciones tensor([10, 10,  4,  5,  0], device='cuda:0')
# Real ....... tensor([10, 10,  4,  5,  0], device='cuda:0')
# val Loss: 0.2952 Acc: 0.9589
#
# Epoch 103/149
# ----------
# train Loss: 0.0140 Acc: 0.9918
# Predicciones tensor([10, 10, 10,  1,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  2], device='cuda:0')
# val Loss: 0.2815 Acc: 0.9581
#
# Epoch 104/149
# ----------
# train Loss: 0.0117 Acc: 0.9925
# Predicciones tensor([10, 10, 10,  2,  1], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  1], device='cuda:0')
# val Loss: 0.2761 Acc: 0.9593
#
# Epoch 105/149
# ----------
# train Loss: 0.0118 Acc: 0.9924
# Predicciones tensor([10, 10, 10,  2,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  7], device='cuda:0')
# val Loss: 0.2784 Acc: 0.9590
#
# Epoch 106/149
# ----------
# train Loss: 0.0126 Acc: 0.9921
# Predicciones tensor([10, 10, 10,  1,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  7], device='cuda:0')
# val Loss: 0.2558 Acc: 0.9604
#
# Epoch 107/149
# ----------
# train Loss: 0.0127 Acc: 0.9922
# Predicciones tensor([10, 10, 10,  1,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  7], device='cuda:0')
# val Loss: 0.2919 Acc: 0.9584
#
# Epoch 108/149
# ----------
# train Loss: 0.0115 Acc: 0.9926
# Predicciones tensor([10, 10, 10,  4,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  2], device='cuda:0')
# val Loss: 0.2980 Acc: 0.9589
#
# Epoch 109/149
# ----------
# train Loss: 0.0116 Acc: 0.9925
# Predicciones tensor([10, 10, 10,  1,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  7], device='cuda:0')
# val Loss: 0.2696 Acc: 0.9601
#
# Epoch 110/149
# ----------
# train Loss: 0.0131 Acc: 0.9921
# Predicciones tensor([10, 10,  3,  1,  1], device='cuda:0')
# Real ....... tensor([10, 10,  3,  6,  9], device='cuda:0')
# val Loss: 0.3207 Acc: 0.9553
#
# Epoch 111/149
# ----------
# train Loss: 0.0137 Acc: 0.9920
# Predicciones tensor([10, 10, 10,  7,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  7,  6], device='cuda:0')
# val Loss: 0.2643 Acc: 0.9605
#
# Epoch 112/149
# ----------
# train Loss: 0.0117 Acc: 0.9926
# Predicciones tensor([10, 10, 10,  2,  6], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  6], device='cuda:0')
# val Loss: 0.2734 Acc: 0.9615
#
# Epoch 113/149
# ----------
# train Loss: 0.0118 Acc: 0.9925
# Predicciones tensor([10, 10, 10,  3,  6], device='cuda:0')
# Real ....... tensor([10, 10, 10,  3,  6], device='cuda:0')
# val Loss: 0.2878 Acc: 0.9596
#
# Epoch 114/149
# ----------
# train Loss: 0.0132 Acc: 0.9922
# Predicciones tensor([10, 10, 10, 10,  6], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  6], device='cuda:0')
# val Loss: 0.2894 Acc: 0.9588
#
# Epoch 115/149
# ----------
# train Loss: 0.0121 Acc: 0.9924
# Predicciones tensor([10, 10,  3,  8,  5], device='cuda:0')
# Real ....... tensor([10, 10,  3,  8,  5], device='cuda:0')
# val Loss: 0.2843 Acc: 0.9593
#
# Epoch 116/149
# ----------
# train Loss: 0.0125 Acc: 0.9922
# Predicciones tensor([10, 10, 10, 10,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  2], device='cuda:0')
# val Loss: 0.2730 Acc: 0.9598
#
# Epoch 117/149
# ----------
# train Loss: 0.0125 Acc: 0.9921
# Predicciones tensor([10, 10, 10,  7,  1], device='cuda:0')
# Real ....... tensor([10, 10, 10,  3,  1], device='cuda:0')
# val Loss: 0.2897 Acc: 0.9583
#
# Epoch 118/149
# ----------
# train Loss: 0.0104 Acc: 0.9931
# Predicciones tensor([10, 10, 10,  2,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  2], device='cuda:0')
# val Loss: 0.2741 Acc: 0.9607
#
# Epoch 119/149
# ----------
# train Loss: 0.0106 Acc: 0.9929
# Predicciones tensor([10, 10, 10, 10,  8], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  8], device='cuda:0')
# val Loss: 0.2936 Acc: 0.9602
#
# Epoch 120/149
# ----------
# train Loss: 0.0115 Acc: 0.9927
# Predicciones tensor([10, 10, 10,  5,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10,  5,  7], device='cuda:0')
# val Loss: 0.2745 Acc: 0.9619
#
# Epoch 121/149
# ----------
# train Loss: 0.0109 Acc: 0.9930
# Predicciones tensor([10, 10, 10,  1,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  2], device='cuda:0')
# val Loss: 0.2776 Acc: 0.9598
#
# Epoch 122/149
# ----------
# train Loss: 0.0119 Acc: 0.9927
# Predicciones tensor([10, 10, 10, 10,  8], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  8], device='cuda:0')
# val Loss: 0.2665 Acc: 0.9613
#
# Epoch 123/149
# ----------
# train Loss: 0.0107 Acc: 0.9928
# Predicciones tensor([10, 10, 10,  1,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  9], device='cuda:0')
# val Loss: 0.2941 Acc: 0.9595
#
# Epoch 124/149
# ----------
# train Loss: 0.0108 Acc: 0.9928
# Predicciones tensor([10, 10, 10,  1,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  2], device='cuda:0')
# val Loss: 0.2947 Acc: 0.9603
#
# Epoch 125/149
# ----------
# train Loss: 0.0106 Acc: 0.9929
# Predicciones tensor([10, 10, 10,  4,  6], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  6], device='cuda:0')
# val Loss: 0.2731 Acc: 0.9618
#
# Epoch 126/149
# ----------
# train Loss: 0.0110 Acc: 0.9927
# Predicciones tensor([10, 10, 10,  2,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  9], device='cuda:0')
# val Loss: 0.3020 Acc: 0.9590
#
# Epoch 127/149
# ----------
# train Loss: 0.0111 Acc: 0.9927
# Predicciones tensor([10, 10, 10,  6,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10,  5,  7], device='cuda:0')
# val Loss: 0.2937 Acc: 0.9587
#
# Epoch 128/149
# ----------
# train Loss: 0.0108 Acc: 0.9929
# Predicciones tensor([10, 10, 10,  2,  1], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  1], device='cuda:0')
# val Loss: 0.2645 Acc: 0.9616
#
# Epoch 129/149
# ----------
# train Loss: 0.0093 Acc: 0.9933
# Predicciones tensor([10, 10, 10,  4,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  8], device='cuda:0')
# val Loss: 0.2770 Acc: 0.9618
#
# Epoch 130/149
# ----------
# train Loss: 0.0099 Acc: 0.9932
# Predicciones tensor([10, 10, 10, 10,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  9], device='cuda:0')
# val Loss: 0.2810 Acc: 0.9612
#
# Epoch 131/149
# ----------
# train Loss: 0.0121 Acc: 0.9926
# Predicciones tensor([10, 10, 10,  6,  8], device='cuda:0')
# Real ....... tensor([10, 10, 10,  6,  8], device='cuda:0')
# val Loss: 0.2905 Acc: 0.9604
#
# Epoch 132/149
# ----------
# train Loss: 0.0124 Acc: 0.9925
# Predicciones tensor([10, 10, 10,  1,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  9], device='cuda:0')
# val Loss: 0.2840 Acc: 0.9600
#
# Epoch 133/149
# ----------
# train Loss: 0.0100 Acc: 0.9929
# Predicciones tensor([10, 10,  5,  6,  5], device='cuda:0')
# Real ....... tensor([10, 10,  5,  6,  5], device='cuda:0')
# val Loss: 0.2917 Acc: 0.9592
#
# Epoch 134/149
# ----------
# train Loss: 0.0091 Acc: 0.9934
# Predicciones tensor([10, 10, 10,  2,  1], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  1], device='cuda:0')
# val Loss: 0.2848 Acc: 0.9620
#
# Epoch 135/149
# ----------
# train Loss: 0.0103 Acc: 0.9929
# Predicciones tensor([10, 10, 10,  8,  3], device='cuda:0')
# Real ....... tensor([10, 10, 10,  8,  3], device='cuda:0')
# val Loss: 0.2966 Acc: 0.9594
#
# Epoch 136/149
# ----------
# train Loss: 0.0105 Acc: 0.9929
# Predicciones tensor([10, 10, 10, 10,  8], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  8], device='cuda:0')
# val Loss: 0.2738 Acc: 0.9616
#
# Epoch 137/149
# ----------
# train Loss: 0.0086 Acc: 0.9936
# Predicciones tensor([10, 10, 10,  3,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10,  3,  7], device='cuda:0')
# val Loss: 0.2956 Acc: 0.9603
#
# Epoch 138/149
# ----------
# train Loss: 0.0106 Acc: 0.9930
# Predicciones tensor([10, 10, 10, 10,  8], device='cuda:0')
# Real ....... tensor([10, 10, 10, 10,  8], device='cuda:0')
# val Loss: 0.2919 Acc: 0.9602
#
# Epoch 139/149
# ----------
# train Loss: 0.0085 Acc: 0.9937
# Predicciones tensor([10, 10, 10,  5,  7], device='cuda:0')
# Real ....... tensor([10, 10, 10,  5,  7], device='cuda:0')
# val Loss: 0.2995 Acc: 0.9598
#
# Epoch 140/149
# ----------
# train Loss: 0.0085 Acc: 0.9935
# Predicciones tensor([10, 10, 10,  1,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  5], device='cuda:0')
# val Loss: 0.2932 Acc: 0.9602
#
# Epoch 141/149
# ----------
# train Loss: 0.0093 Acc: 0.9933
# Predicciones tensor([10, 10, 10,  3,  5], device='cuda:0')
# Real ....... tensor([10, 10, 10,  3,  5], device='cuda:0')
# val Loss: 0.3254 Acc: 0.9577
#
# Epoch 142/149
# ----------
# train Loss: 0.0107 Acc: 0.9930
# Predicciones tensor([10, 10, 10,  1,  0], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  0], device='cuda:0')
# val Loss: 0.2816 Acc: 0.9607
#
# Epoch 143/149
# ----------
# train Loss: 0.0102 Acc: 0.9933
# Predicciones tensor([10, 10, 10,  4,  8], device='cuda:0')
# Real ....... tensor([10, 10, 10,  4,  8], device='cuda:0')
# val Loss: 0.3025 Acc: 0.9588
#
# Epoch 144/149
# ----------
# train Loss: 0.0082 Acc: 0.9938
# Predicciones tensor([10, 10, 10,  2,  4], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  4], device='cuda:0')
# val Loss: 0.2733 Acc: 0.9638
#
# Epoch 145/149
# ----------
# train Loss: 0.0095 Acc: 0.9932
# Predicciones tensor([10, 10, 10,  1,  3], device='cuda:0')
# Real ....... tensor([10, 10, 10,  1,  3], device='cuda:0')
# val Loss: 0.2963 Acc: 0.9613
#
# Epoch 146/149
# ----------
# train Loss: 0.0090 Acc: 0.9934
# Predicciones tensor([10, 10, 10,  2,  9], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  9], device='cuda:0')
# val Loss: 0.2927 Acc: 0.9604
#
# Epoch 147/149
# ----------
# train Loss: 0.0085 Acc: 0.9936
# Predicciones tensor([10, 10, 10,  2,  2], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  2], device='cuda:0')
# val Loss: 0.3109 Acc: 0.9607
#
# Epoch 148/149
# ----------
# train Loss: 0.0099 Acc: 0.9931
# Predicciones tensor([10, 10, 10,  2,  8], device='cuda:0')
# Real ....... tensor([10, 10, 10,  2,  8], device='cuda:0')
# val Loss: 0.2950 Acc: 0.9596
#
# Epoch 149/149
# ----------
# train Loss: 0.0086 Acc: 0.9936
# Predicciones tensor([10, 10, 10,  3,  6], device='cuda:0')
# Real ....... tensor([10, 10, 10,  3,  6], device='cuda:0')
# val Loss: 0.2705 Acc: 0.9634
#
# Training complete in 129m 55s
# Best val Acc: 0.963789

# %% [markdown]
# ## Save trained model

# %%
PATH = './best_model.pth'
torch.save(best_model.state_dict(), PATH)

# %% [markdown]
# ## Load model and test it with extra dataset

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
PATH = './best_model.pth'
trained_model = model.vgg11_bn()
trained_model = trained_model.to(device)
trained_model.load_state_dict(torch.load(PATH))
trained_model.eval()
correctos = 0.0
incorrectos = 0
total_imagenes = 0
for i, data in enumerate(test_loader,0):
    image = data["image"].to(device, dtype=torch.float)
    label = data["labels"].to(device, dtype=torch.long)
    totalbatch = len(image)
    total_imagenes += totalbatch
    out = trained_model(image)
    _,preds = torch.max(out, 1)
    cor = preds.eq(label).sum()
    correctos += cor
    incorrectos += totalbatch*5 - (cor)
    
print(correctos, incorrectos, total_imagenes)
x = ((correctos.item())/(total_imagenes*5))*100
print("accuracy {}%".format(x))
# Out:
# tensor(936273, device='cuda:0') tensor(74927, device='cuda:0') 202240
# accuracy 92.59028876582278%

# %% [markdown]
# ## Plot Validation Accuracy vs. Number of Training Epochs

# %%
plt.title("Validation Accuracy vs. Number of Training Epochs")
shist = [h.cpu().numpy() for h in scratch_hist]
plt.plot(range(1,150+1),shist,label="Scratch")
plt.xticks(np.arange(0, 151, 15.0))
plt.legend()
plt.show()
